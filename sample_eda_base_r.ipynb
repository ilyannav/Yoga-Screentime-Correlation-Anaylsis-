# %%
library(readxl)
library(haven)
library(tidyverse)


my_data <- read.csv("/content/Sample_Dataset_2019.csv")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.0     ✔ readr     2.2.0
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.2     ✔ tibble    3.3.1
# ✔ lubridate 1.9.5     ✔ tidyr     1.3.2
# ✔ purrr     1.2.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
## Part 2: Data Management ###################################################

##### Step 1: Look at the data we imported into R ############################

#' View the data as a table in a pop-up window using View()

View(my_data)


#' Look at first and last 5 rows of the dataframe using head() and tail()

head(my_data)

tail(my_data)

#' Print the names of the variables in the dataframe using colnames()

colnames(my_data)


#' Print the types of all variables in the dataframe str()

str(my_data)

#' Print min/max/median for all variables in the dataframe using summary()

summary(my_data)
# Out:
#     ids   bday       Gender Age Athlete Smoking Height Weight Mile MileMinDur ⋯
# 1   20055 1995-08-06  0     24  1        1      64.5   127.5  494  0:08:14    ⋯
# 2   20075             0     NA  0        1      74.0   195.5  441  0:07:21    ⋯
# 3   20087             0     NA  0        1      68.5   153.0   NA             ⋯
# 4   20088 2001-01-08  1     18  0       NA      67.5   158.5  514  0:08:34    ⋯
# 5   20135 1998-12-26  0     20  0        1      75.0   152.0  450  0:07:30    ⋯
# 6   20161 2000-12-02  1     18  1        1      73.5   177.5  403  0:06:43    ⋯
# 7   20188 2001-08-06  0     18  0        1      76.0   181.0   NA             ⋯
# 8   20215 1997-08-05  0     22  0        2      76.0   155.5  563  0:09:23    ⋯
# 9   20250 1994-12-14 NA     24  0        1      66.5   119.0  653  0:10:53    ⋯
# 10  20354 1999-08-05  1     20  0        1      62.5   147.5  684  0:11:24    ⋯
# 11  20640 2000-05-31  1     19  0        1      63.0   161.0  798  0:13:18    ⋯
# ...

# %%
##### Step 2: Computing new variables ##########################################

#' Use the $ operator to access a single variable within the dataframe (e.g. to find its mean)

$???

  #' See if you can use this to find the mean of variable SleepTime:

  mean(???$???)

#' If the above result returned NA, it's because the variable had missing values.
#' To have R ignore the missing values and calculate the sample mean using the
#' nonmissing observations, add the na.rm=TRUE argument.
mean(???$???, na.rm=TRUE)


#' How can we add a new variable to an existing dataframe?
#' We combine the $ notation with the assignment operator!

???$SleepTimeMinutes <- ???$SleepTime*60

???$missing_SleepTime <- is.na(???$SleepTime)

???$RankLabeled <- factor(???$Rank,
                          levels=c(1, 2, 3, 4),
                          labels=c("Freshman", "Sophomore", "Junior", "Senior"))

???$RankOrdered <- ordered(???$Rank,
                           levels=c(1, 2, 3, 4),
                           labels=c("Freshman", "Sophomore", "Junior", "Senior"))

# %%
##### Step 3: Filtering rows/Access rows within the dataset ####################

#' Use the subset() function with the subset argument to filter the rows in
#' the dataset to just those meeting a logical condition
#'    logical operators in R include:
#'      ==    equal to
#'      !=    not equal to
#'      >     greater than
#'      >=    greater than or equal to
#'      <     less than
#'      <=    less than or equal to
#'      !     "not" (used as prefix in front of functions that return TRUE/FALSE)
#'    logical functions in R include (but are not limited to!):
#'      is.na()       returns TRUE if missing, FALSE if nonmissing
#'      is.numeric()  returns TRUE if input is numeric, FALSE otherwise
#'      is.character()  returns TRUE if input is character, FALSE otherwise

subset(???, subset=???)

##### Step 4: Selecting columns/Access the variables within the dataset ########

#' Use the subset() function to extract multiple columns from the dataset
#' by name, position, or pattern

#' Use vectors to supply the names of more than one variables (replace "var1" and "var2 with actual variable names from the data)
subset(???, select=c(var1, var2))

#' You can add a minus sign (-) in front of the vector to instead REMOVE those variables
subset(???, select=-c(var1, var2))

# %%
## Part 3: Data Analysis ###################################################

#' Try making a frequency table of variable Rank using table()

table(???)

#' If you want to add the totals, wrap the table() function in addmargins() function:

addmargins(table(???))

#' Does this number match the number of rows in the dataset? If not,
#' what do you think the issue is?


#' Compute Pearson correlation between two variables using cor()
#'    SleepTime and StudyTime

cor(???, ???)

#' What happens when we pass the entire dataframe object to the cor() function?

cor(???)

#' We get an error message if we try to pass the entire dataframe to cor()
#' because the dataframe contains non-numeric variables.
#' Let's create a dataset with just the main numeric variables (SleepTime, StudyTime),
#' which can then safely be passed to cor().
#' The subset() function can select a range of columns using the select argument.




#' Fit linear regression model using lm()
#' The first argument to lm() is the model formula, which follows the syntax:
#'      y ~ x1 + x2 + ...
#'   where y is the dependent variable and x1, x2, ... are independent variables

lm(y ~ x1 + x2, data=???)

#' Model formula with interaction (this syntax will fit all main effects and the two-way interaction)
lm(y ~ x1*x2, data=???)
